# %% [markdown]
# # Run + verify
#
# This notebook focuses on reproducible execution and verification.

# %%
import glob
from pathlib import Path

# Run a strict-pack demo
# !python -m omphalos run --config config/runs/strict_demo.yaml

run_dir = sorted(glob.glob('artifacts/runs/run-*'))[-1]
# !python -m omphalos verify --run-dir {run_dir}
