# %% [markdown]
# # Publishability scan
#
# Run the publishability scan and inspect findings.

# %%
import glob, json, os

run_dir = sorted(glob.glob('artifacts/runs/run-*'))[-1]
out = os.path.join(run_dir,'reports','publishability_scan_notebook.json')
# !python -m omphalos publishability scan --path {run_dir} --out {out}
print(json.loads(open(out,'r',encoding='utf-8').read())['status'])
