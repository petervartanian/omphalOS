# %% [markdown]
# # Release bundles
#
# Build and verify a release bundle, then inspect its manifest.

# %%
import glob, json, os

run_dir = sorted(glob.glob('artifacts/runs/run-*'))[-1]
out = os.path.join('artifacts','releases', os.path.basename(run_dir) + '.tar.gz')
# !python -m omphalos release build --run-dir {run_dir} --out {out}
# !python -m omphalos release verify --bundle {out}
